# %%
import pandas as pd

# %%
df = pd.read_excel(r"/Users/pro/Downloads/Pandas_Tutorial/Customer Call List.xlsx")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.drop_duplicates()
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.drop(columns = 'Not_Useful_Column')
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df['Last_Name'].str.lstrip('...')
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11         Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# 20      Skywalker
# Name: Last_Name, dtype: object

# %%
#df['Last_Name'] = df['Last_Name'].str.lstrip('...')
#df['Last_Name'] = df['Last_Name'].str.lstrip('/')
df['Last_Name'] = df['Last_Name'].str.strip('123_/,.')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
#df['Phone_Number'] = df['Phone_Number'].str.replace('[^A-Za-z0-9/|]',  '')
df['Phone_Number']= df['Phone_Number'].apply(lambda x: str(x))

df['Phone_Number'].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' +  x[6:10])
# Out:
# 0     123--54-5-54
# 1     123-/64-3/97
# 2     706-695-0392
# 3     123--54-3-23
# 4     876-|67-8|34
# 5     304--76-2-24
# 6            nan--
# 7     876-|67-8|34
# 8            N/a--
# 9     123--54-5-54
# 10           nan--
# 11    706-695-0392
# 12    123--54-3-23
# 13    876-|67-8|34
# 14    304--76-2-24
# 15    123--54-5-54
# 16    123-/64-3/97
# 17    706-695-0392
# 18           N/a--
# 19    876-|67-8|34
# 20    876-|67-8|34
# Name: Phone_Number, dtype: object

# %%
df['Phone_Number'] = df['Phone_Number'].str.replace('N/a', '')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           nan
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           nan
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
df[["Street", "State", "Zip_Code"]] = df["Address"].str.split(',',  expand = True) 
#df[["Street", "State", "Zip_Code"]] = df["Address"].str.split(',', expand=True).iloc[:, :3].fillna('')

df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           nan
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           nan
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('Yes', 'Y')
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('No', 'N')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           nan
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           nan
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
#df = df.replace('N/a', '')
#df = df.replace('NaN', '')
df = df.fillna('')

# %%
for x in df.index:
    if df.loc[x, "Do_Not_Contact"] == 'Y':
        df.drop(x, inplace =True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 2         1003     Walter       White    7066950392
# 4         1005        Jon        Snow  876|678|3469
# 6         1007       Jeff      Winger           nan
# 7         1008   Sherlock      Holmes  876|678|3469
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           nan
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# 17        1018      Clark        Kent    7066950392
# 19        1020     Anakin   Skywalker  876|678|3469
# 20        1020     Anakin   Skywalker  876|678|3469
#
#                            Address Paying Customer Do_Not_Contact  \
# ...

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
for x in df.index:
    if df.loc[x, "Phone_Number"] == '':
        df.drop(x, inplace =True)
df

#another way to drop null values
df = df.dropna(subset= "Phone_Number", inplace =True)

# %%
df.drop(columns = "Address")
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 2         1003     Walter       White    7066950392               N
# 4         1005        Jon        Snow  876|678|3469               Y
# 6         1007       Jeff      Winger           nan              No
# 7         1008   Sherlock      Holmes  876|678|3469               N
# 9         1010      Peter      Parker  123-545-5421             Yes
# 10        1011    Samwise      Gamgee           nan             Yes
# 11        1012      Harry      Potter    7066950392               Y
# 12        1013        Don      Draper  123-543-2345             Yes
# 13        1014     Leslie       Knope  876|678|3469             Yes
# 14        1015       Toby  Flenderson  304-762-2467               N
# 15        1016        Ron     Weasley  123-545-5421              No
# 16        1017   Michael        Scott  123/643/9775             Yes
# ...

# %%
df.reset_index(drop = True)
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1003     Walter       White    7066950392
# 2         1005        Jon        Snow  876|678|3469
# 3         1007       Jeff      Winger           nan
# 4         1008   Sherlock      Holmes  876|678|3469
# 5         1010      Peter      Parker  123-545-5421
# 6         1011    Samwise      Gamgee           nan
# 7         1012      Harry      Potter    7066950392
# 8         1013        Don      Draper  123-543-2345
# 9         1014     Leslie       Knope  876|678|3469
# 10        1015       Toby  Flenderson  304-762-2467
# 11        1016        Ron     Weasley  123-545-5421
# 12        1017   Michael        Scott  123/643/9775
# 13        1018      Clark        Kent    7066950392
# 14        1020     Anakin   Skywalker  876|678|3469
# 15        1020     Anakin   Skywalker  876|678|3469
#
#                            Address Paying Customer Do_Not_Contact  \
# ...
